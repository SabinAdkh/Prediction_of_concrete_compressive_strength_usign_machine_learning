# %%
import numpy as np
import pandas as pd
from pandas_profiling import profile_report
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("seaborn-darkgrid")
# %matplotlib inline

# %%
df = pd.read_excel("hpc_compressive_strength.xlsx")
# df = pd.read_csv("concrete_data.csv")
df.head()
# Out:
#    Cement (kg in a m^3 mixture)  Blast Furnace Slag (kg in a m^3 mixture)  \
# 0                         540.0                                       0.0
# 1                         540.0                                       0.0
# 2                         332.5                                     142.5
# 3                         332.5                                     142.5
# 4                         198.6                                     132.4
#
#    Fly Ash (kg in a m^3 mixture)  Water (kg in a m^3 mixture)  \
# 0                            0.0                        162.0
# 1                            0.0                        162.0
# 2                            0.0                        228.0
# 3                            0.0                        228.0
# 4                            0.0                        192.0
#
#    Superplasticizer (kg in a m^3 mixture)  \
# 0                                     2.5
# 1                                     2.5
# 2                                     0.0
# 3                                     0.0
# 4                                     0.0
#
#    Coarse Aggregate (kg in a m^3 mixture)  \
# 0                                  1040.0
# 1                                  1055.0
# 2                                   932.0
# 3                                   932.0
# 4                                   978.4
#
#    Fine Aggregate (kg in a m^3 mixture)  Age (day)  \
# 0                                 676.0         28
# 1                                 676.0         28
# 2                                 594.0        270
# 3                                 594.0        365
# 4                                 825.5        360
#
#    Concrete compressive strength (MPa, megapascals)
# 0                                          79.986111
# 1                                          61.887366
# 2                                          40.269535
# 3                                          41.052780
# 4                                          44.296075

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1133 entries, 0 to 1132
# Data columns (total 9 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Cement (kg in a m^3 mixture)                       1133 non-null   float64
#  1   Blast Furnace Slag (kg in a m^3 mixture)           1133 non-null   float64
#  2   Fly Ash (kg in a m^3 mixture)                      1133 non-null   float64
#  3   Water (kg in a m^3 mixture)                        1133 non-null   float64
#  4   Superplasticizer (kg in a m^3 mixture)             1133 non-null   float64
#  5   Coarse Aggregate (kg in a m^3 mixture)             1133 non-null   float64
#  6   Fine Aggregate (kg in a m^3 mixture)               1133 non-null   float64
#  7   Age (day)                                          1133 non-null   int64
#  8   Concrete compressive strength (MPa, megapascals)   1133 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 79.8 KB

# %%
# df.profile_report()

# %%
df.describe().T
# Out:
#                                                     count        mean  \
# Cement (kg in a m^3 mixture)                       1133.0  276.504590
# Blast Furnace Slag (kg in a m^3 mixture)           1133.0   74.266240
# Fly Ash (kg in a m^3 mixture)                      1133.0   62.807811
# Water (kg in a m^3 mixture)                        1133.0  182.984687
# Superplasticizer (kg in a m^3 mixture)             1133.0    6.415538
# Coarse Aggregate (kg in a m^3 mixture)             1133.0  964.833142
# Fine Aggregate (kg in a m^3 mixture)               1133.0  770.490335
# Age (day)                                          1133.0   44.056487
# Concrete compressive strength (MPa, megapascals)   1133.0   35.837980
#
#                                                           std         min  \
# Cement (kg in a m^3 mixture)                       103.469947  102.000000
# Blast Furnace Slag (kg in a m^3 mixture)            84.246758    0.000000
# Fly Ash (kg in a m^3 mixture)                       71.583164    0.000000
# Water (kg in a m^3 mixture)                         21.713923  121.750000
# Superplasticizer (kg in a m^3 mixture)               5.796357    0.000000
# Coarse Aggregate (kg in a m^3 mixture)              82.788223  708.000000
# Fine Aggregate (kg in a m^3 mixture)                79.373870  594.000000
# Age (day)                                           60.441327    1.000000
# Concrete compressive strength (MPa, megapascals)    16.100509    2.331808
#
#                                                           25%         50%  \
# Cement (kg in a m^3 mixture)                       190.000000  266.000000
# Blast Furnace Slag (kg in a m^3 mixture)             0.000000   26.000000
# Fly Ash (kg in a m^3 mixture)                        0.000000    0.000000
# Water (kg in a m^3 mixture)                        167.000000  185.700000
# Superplasticizer (kg in a m^3 mixture)               0.000000    6.700000
# Coarse Aggregate (kg in a m^3 mixture)             919.000000  966.800000
# Fine Aggregate (kg in a m^3 mixture)               720.000000  777.500000
# Age (day)                                           14.000000   28.000000
# Concrete compressive strength (MPa, megapascals)    24.393661   34.673748
#
#                                                           75%          max
# Cement (kg in a m^3 mixture)                        342.00000   540.000000
# Blast Furnace Slag (kg in a m^3 mixture)            141.30000   359.400000
# Fly Ash (kg in a m^3 mixture)                       121.97000   260.000000
# Water (kg in a m^3 mixture)                         193.80000   247.000000
# Superplasticizer (kg in a m^3 mixture)               10.16000    32.200000
# Coarse Aggregate (kg in a m^3 mixture)             1026.60000  1145.000000
# Fine Aggregate (kg in a m^3 mixture)                821.00000   992.600000
# Age (day)                                            28.00000   365.000000
# Concrete compressive strength (MPa, megapascals)     44.86834    82.599225

# %%
# Data Analy

# %%
# Duplicate rows
mask = df.duplicated(keep='first')
df[mask]
# Out:
#      Cement (kg in a m^3 mixture)  Blast Furnace Slag (kg in a m^3 mixture)  \
# 77                          425.0                                     106.3
# 80                          425.0                                     106.3
# 86                          362.6                                     189.0
# 88                          362.6                                     189.0
# 91                          362.6                                     189.0
# 100                         425.0                                     106.3
# 103                         425.0                                     106.3
# 109                         362.6                                     189.0
# 111                         362.6                                     189.0
# 123                         425.0                                     106.3
# 126                         425.0                                     106.3
# 132                         362.6                                     189.0
# 134                         362.6                                     189.0
# 137                         362.6                                     189.0
# 146                         425.0                                     106.3
# 149                         425.0                                     106.3
# 155                         362.6                                     189.0
# 157                         362.6                                     189.0
# 160                         362.6                                     189.0
# 169                         425.0                                     106.3
# 172                         425.0                                     106.3
# 177                         362.6                                     189.0
# 179                         362.6                                     189.0
# 182                         362.6                                     189.0
# 809                         252.0                                       0.0
#
#      Fly Ash (kg in a m^3 mixture)  Water (kg in a m^3 mixture)  \
# 77                             0.0                        153.5
# 80                             0.0                        153.5
# 86                             0.0                        164.9
# 88                             0.0                        164.9
# 91                             0.0                        164.9
# 100                            0.0                        153.5
# 103                            0.0                        153.5
# 109                            0.0                        164.9
# 111                            0.0                        164.9
# 123                            0.0                        153.5
# 126                            0.0                        153.5
# 132                            0.0                        164.9
# 134                            0.0                        164.9
# 137                            0.0                        164.9
# 146                            0.0                        153.5
# 149                            0.0                        153.5
# 155                            0.0                        164.9
# 157                            0.0                        164.9
# 160                            0.0                        164.9
# 169                            0.0                        153.5
# 172                            0.0                        153.5
# 177                            0.0                        164.9
# 179                            0.0                        164.9
# 182                            0.0                        164.9
# 809                            0.0                        185.0
#
#      Superplasticizer (kg in a m^3 mixture)  \
# 77                                     16.5
# 80                                     16.5
# 86                                     11.6
# 88                                     11.6
# 91                                     11.6
# 100                                    16.5
# 103                                    16.5
# 109                                    11.6
# 111                                    11.6
# 123                                    16.5
# 126                                    16.5
# 132                                    11.6
# 134                                    11.6
# 137                                    11.6
# 146                                    16.5
# 149                                    16.5
# 155                                    11.6
# 157                                    11.6
# 160                                    11.6
# 169                                    16.5
# 172                                    16.5
# 177                                    11.6
# 179                                    11.6
# 182                                    11.6
# 809                                     0.0
#
#      Coarse Aggregate (kg in a m^3 mixture)  \
# 77                                    852.1
# 80                                    852.1
# 86                                    944.7
# 88                                    944.7
# 91                                    944.7
# 100                                   852.1
# 103                                   852.1
# 109                                   944.7
# 111                                   944.7
# 123                                   852.1
# 126                                   852.1
# 132                                   944.7
# 134                                   944.7
# 137                                   944.7
# 146                                   852.1
# 149                                   852.1
# 155                                   944.7
# 157                                   944.7
# 160                                   944.7
# 169                                   852.1
# 172                                   852.1
# 177                                   944.7
# 179                                   944.7
# 182                                   944.7
# 809                                  1111.0
#
#      Fine Aggregate (kg in a m^3 mixture)  Age (day)  \
# 77                                  887.1          3
# 80                                  887.1          3
# 86                                  755.8          3
# 88                                  755.8          3
# 91                                  755.8          3
# 100                                 887.1          7
# 103                                 887.1          7
# 109                                 755.8          7
# 111                                 755.8          7
# 123                                 887.1         28
# 126                                 887.1         28
# 132                                 755.8         28
# 134                                 755.8         28
# 137                                 755.8         28
# 146                                 887.1         56
# 149                                 887.1         56
# 155                                 755.8         56
# 157                                 755.8         56
# 160                                 755.8         56
# 169                                 887.1         91
# 172                                 887.1         91
# 177                                 755.8         91
# 179                                 755.8         91
# 182                                 755.8         91
# 809                                 784.0         28
#
#      Concrete compressive strength (MPa, megapascals)
# 77                                           33.398217
# 80                                           33.398217
# 86                                           35.301171
# 88                                           35.301171
# 91                                           35.301171
# 100                                          49.201007
# 103                                          49.201007
# 109                                          55.895819
# 111                                          55.895819
# 123                                          60.294676
# 126                                          60.294676
# 132                                          71.298713
# 134                                          71.298713
# 137                                          71.298713
# 146                                          64.300532
# 149                                          64.300532
# 155                                          77.297154
# 157                                          77.297154
# 160                                          77.297154
# 169                                          65.196851
# 172                                          65.196851
# 177                                          79.296635
# 179                                          79.296635
# 182                                          79.296635
# 809                                          19.691435

# %%
# Remove duplicate rows
df = df.loc[~mask]

# %%
# Columns names
df.columns
# Out:
# Index(['Cement (kg in a m^3 mixture)',
#        'Blast Furnace Slag (kg in a m^3 mixture)',
#        'Fly Ash (kg in a m^3 mixture)', 'Water (kg in a m^3 mixture)',
#        'Superplasticizer (kg in a m^3 mixture)',
#        'Coarse Aggregate (kg in a m^3 mixture)',
#        'Fine Aggregate (kg in a m^3 mixture)', 'Age (day)',
#        'Concrete compressive strength (MPa, megapascals) '],
#       dtype='object')

# %%
column_names = ["Cement",
               "Blast_Furnace_Slag",
               "Fly_Ash",
               "Water",
               "Superplasticizer",
               "Coarse_Aggregate",
               "Fine_Aggregate",
               "Age (days)",
               "Concrete_compressive_strength"]

# Changing the column names
df.columns = column_names
df.head()
# Out:
#    Cement  Blast_Furnace_Slag  Fly_Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse_Aggregate  Fine_Aggregate  Age (days)  Concrete_compressive_strength
# 0            1040.0           676.0          28                      79.986111
# 1            1055.0           676.0          28                      61.887366
# 2             932.0           594.0         270                      40.269535
# 3             932.0           594.0         365                      41.052780
# 4             978.4           825.5         360                      44.296075

# %%
# Cement > 250
# (df['Cement'] < 250).value_counts()

# %%
# mask = (df['Cement'] > 250)
# df = df.loc[~mask]

# %% [markdown]
# ## Data Visualization

# %%
# Plotting correlation using heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='viridis')
plt.title("Pearson's Correlation")
# Out:
# Text(0.5, 1.0, "Pearson's Correlation")

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(method='spearman'), annot=True, cmap='viridis') ## Captures non linear realtionship between the varaibles
plt.title("Spearman Rank Correlation")
# Out:
# Text(0.5, 1.0, 'Spearman Rank Correlation')

# %%
# Correlation Table
columns = df.corr().Concrete_compressive_strength.index
pearson_corr = df.corr().Concrete_compressive_strength.values
spearman_corr = df.corr(method='spearman').Concrete_compressive_strength.values

corr_table = pd.DataFrame({"Pearson's Correlation": pearson_corr,
                          "Spearmn Rank Correlation": spearman_corr}, index=columns)
corr_table
# Out:
#                                Pearson's Correlation  Spearmn Rank Correlation
# Cement                                      0.478399                  0.446446
# Blast_Furnace_Slag                          0.089009                  0.115385
# Fly_Ash                                    -0.038046                 -0.011253
# Water                                      -0.257774                 -0.265436
# Superplasticizer                            0.334673                  0.309019
# Coarse_Aggregate                           -0.140021                 -0.169226
# Fine_Aggregate                             -0.184846                 -0.195905
# Age (days)                                  0.330978                  0.594191
# Concrete_compressive_strength               1.000000                  1.000000

# %%
corr = df.corr().index[:-1]
features = df.corr().Concrete_compressive_strength.values[:-1]

plt.figure(figsize=(10, 8))
sns.barplot(features, corr)
# plt.title("Spearman Rank Correlation")
plt.text(0, -1, "Pearson's Correlation", fontdict={'fontsize':15})
plt.text(-0.04, -0.6, "Concrete Compressive Strength", fontdict={'fontsize':13})
# Out:
# /home/sadkh/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(-0.04, -0.6, 'Concrete Compressive Strength')

# %%
corr = df.corr(method='spearman').index[:-1]
features = df.corr(method='spearman').Concrete_compressive_strength.values[:-1]

plt.figure(figsize=(10, 8))
sns.barplot(features, corr)
# plt.title("Spearman Rank Correlation")
plt.text(0, -1, "Spearman Rank Correlation", fontdict={'fontsize':15})
plt.text(0, -0.6, "Concrete Compressive Strength", fontdict={'fontsize':13})
# Out:
# /home/sadkh/miniconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, -0.6, 'Concrete Compressive Strength')

# %% [markdown]
# ## Interaction between features and target variable

# %%
df.columns.to_list()
# Out:
# ['Cement',
#  'Blast_Furnace_Slag',
#  'Fly_Ash',
#  'Water',
#  'Superplasticizer',
#  'Coarse_Aggregate',
#  'Fine_Aggregate',
#  'Age (days)',
#  'Concrete_compressive_strength']

# %%
columns = df.columns.to_list()
fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6), (ax7, ax8)) = plt.subplots(nrows=4, ncols=2, sharey=True, figsize=(10,18))
fig.tight_layout(pad = 3)
axes = [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8]
[sns.scatterplot(x=df[column], y=df["Concrete_compressive_strength"],color='green',edgecolors='yellow',alpha=0.3, ax=ax) for ax, column in zip(axes, columns)]
plt.text(-400, 400, "Interaction Between Features and Target Variable", fontdict={'fontsize':15})
# Out:
# Text(-400, 400, 'Interaction Between Features and Target Variable')

# %%
## Distribution of target variable
plt.figure(figsize = (10, 8))
sns.distplot(df['Concrete_compressive_strength'], bins = 50, rug=True, kde_kws={'color':'green', 'lw':2})
# Out:
# /home/sadkh/miniconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/sadkh/miniconda3/lib/python3.9/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Concrete_compressive_strength', ylabel='Density'>

# %% [markdown]
# # Machine Learning Modeling

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor

# %%
# Features
X = df.drop('Concrete_compressive_strength', axis='columns')
# Target variable
y = df['Concrete_compressive_strength']

# %%
X.shape, y.shape
# Out:
# ((1108, 8), (1108,))

# %%
# Splitting the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((997, 8), (111, 8))

# %%
# # scaling the data
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Using Cross Validation

# %%
models = {"SVM":SVR(kernel="rbf", degree=2, C=100, epsilon=0.01),
         "DTReg":DecisionTreeRegressor(),
         "RFReg":RandomForestRegressor(),
         "GBR":GradientBoostingRegressor(),
         "HGBR":HistGradientBoostingRegressor(),
         "AdBR":AdaBoostRegressor(),
         "XGBR":XGBRegressor(),
         "CatBoostReg":CatBoostRegressor(verbose=None),
         "LGBM":LGBMRegressor()}

accuracy = []
for name, model in models.items():
    print("Training {}".format(name))
    scores = cross_val_score(model, X_train_scaled, y_train, cv=5)
    print("cross val scores of {} : {}".format(name, scores))
    print("Average score of {} : {}".format(name, scores.mean()))
    print("-----------------------------------------------------")
# Out:
# Training SVM
# cross val scores of SVM : [0.86361838 0.8596388  0.86050457 0.87509316 0.87774232]
# Average score of SVM : 0.8673194439735121
# -----------------------------------------------------
# Training DTReg
# cross val scores of DTReg : [0.82547189 0.75459559 0.80470015 0.79807014 0.75771926]
# Average score of DTReg : 0.7881114078362673
# -----------------------------------------------------
# Training RFReg
# cross val scores of RFReg : [0.89785931 0.88971222 0.89620353 0.9024379  0.90692613]
# Average score of RFReg : 0.8986278182177585
# -----------------------------------------------------
# Training GBR
# cross val scores of GBR : [0.86517468 0.87947292 0.88744676 0.87356803 0.89325242]
# Average score of GBR : 0.8797829627309038
# -----------------------------------------------------
# Training HGBR
# cross val scores of HGBR : [0.91479884 0.90627977 0.89648045 0.91142016 0.92286667]
# Average score of HGBR : 0.910369178367098
# -----------------------------------------------------
# Training AdBR
# cross val scores of AdBR : [0.7472487  0.7578461  0.74990596 0.75748003 0.75612536]
# Average score of AdBR : 0.7537212300289754
# -----------------------------------------------------
# Training XGBR
# cross val scores of XGBR : [0.92980332 0.91682225 0.9012643  0.91968387 0.92623395]
# Average score of XGBR : 0.9187615358900952
# -----------------------------------------------------
# Training CatBoostReg
# Learning rate set to 0.039501
# 0:	learn: 15.2478035	total: 48.9ms	remaining: 48.8s
# 1:	learn: 14.9187893	total: 50.6ms	remaining: 25.3s
# 2:	learn: 14.5941711	total: 75ms	remaining: 24.9s
# 3:	learn: 14.2533618	total: 77ms	remaining: 19.2s
# 4:	learn: 13.9600486	total: 79.7ms	remaining: 15.9s
# 5:	learn: 13.6695741	total: 82.2ms	remaining: 13.6s
# 6:	learn: 13.4112353	total: 83.8ms	remaining: 11.9s
# 7:	learn: 13.1391681	total: 86.7ms	remaining: 10.8s
# 996:	learn: 1.9030494	total: 934ms	remaining: 2.81ms
# 997:	learn: 1.9021059	total: 935ms	remaining: 1.87ms
# 998:	learn: 1.9009276	total: 936ms	remaining: 937us
# 999:	learn: 1.8996673	total: 937ms	remaining: 0us
# cross val scores of CatBoostReg : [0.93669722 0.91303872 0.91532466 0.94103607 0.93772195]
# Average score of CatBoostReg : 0.9287637231741614
# -----------------------------------------------------
# Training LGBM
# cross val scores of LGBM : [0.91305205 0.90516125 0.89765458 0.91631229 0.92694549]
# Average score of LGBM : 0.9118251324897588
# -----------------------------------------------------

# %% [markdown]
# ## Support Vector Regressor

# %%
svr= SVR(kernel="rbf", degree=2, C=100, epsilon=0.01)
svr.fit(X_train_scaled, y_train)
svr_preds = svr.predict(X_test_scaled)

# %%
plt.rcParams['figure.figsize'] = (10, 8)
sns.kdeplot(y_test)
sns.kdeplot(svr_preds)
plt.legend(['actual', 'predicted'])

# %%
print("Training Accuracy: {}".format(svr.score(X_train_scaled, y_train)))
print("Testing Accuracy: {}".format(svr.score(X_test_scaled, y_test)))
print("-------------------------------")
print("R Squared: {}".format(r2_score(y_test, svr_preds)))
print("Root Mean Squared Error: {}".format(np.sqrt(mean_squared_error(y_test, svr_preds))))
print("Mean Absolute Error: {}".format(mean_absolute_error(y_test, svr_preds)))
# Out:
# Training Accuracy: 0.9313517277761489
# Testing Accuracy: 0.8455524663214369
# -------------------------------
# R Squared: 0.8455524663214369
# Root Mean Squared Error: 6.065839163788707
# Mean Absolute Error: 3.9304031901358516

# %% [markdown]
# ## Decision Tree Regressor

# %%
dt_reg = DecisionTreeRegressor(max_depth=3)
dt_reg.fit(X_train_scaled, y_train)
dt_preds = dt_reg.predict(X_test_scaled)

# %%
sns.kdeplot(y_test)
sns.kdeplot(dt_preds)
plt.legend(['actual','predicted'])

# %%
print("Training Accuracy: {}".format(dt_reg.score(X_train_scaled, y_train)))
print("Testing Accuracy: {}".format(dt_reg.score(X_test_scaled, y_test)))
print("-------------------------------")
print("R Squared: {}".format(r2_score(y_test, dt_preds)))
print("Root Mean Squared Error: {}".format(np.sqrt(mean_squared_error(y_test, dt_preds))))
print("Mean Absolute Error: {}".format(mean_absolute_error(y_test, dt_preds)))
# Out:
# Training Accuracy: 0.6096070107183575
# Testing Accuracy: 0.5598757451782737
# -------------------------------
# R Squared: 0.5598757451782737
# Root Mean Squared Error: 10.239719342838374
# Mean Absolute Error: 7.993650603133928

# %%
dtc_feature_imp = dt_reg.feature_importances_
dtc_feature_imp
# Out:
# array([0.43223529, 0.        , 0.        , 0.10065746, 0.04480427,
#        0.        , 0.        , 0.42230297])

# %%
sns.barplot(x=dtc_feature_imp, y=df.columns[:-1], orient='h')
plt.title("Decision Tree Feature Importances")
# Out:
# Text(0.5, 1.0, 'Decision Tree Feature Importances')

# %% [markdown]
# ## Random Forest Regressor

# %%
rf_reg = RandomForestRegressor(n_estimators=400,max_depth=5, max_features=5,min_samples_leaf=2, random_state=42)
# rf_reg = RandomForestRegressor()
rf_reg.fit(X_train_scaled, y_train)
rf_preds = rf_reg.predict(X_test_scaled)

# %%
print("Training Accuracy: {}".format(rf_reg.score(X_train_scaled, y_train)))
print("Testing Accuracy: {}".format(rf_reg.score(X_test_scaled, y_test)))
print("-------------------------------")
print("R Squared: {}".format(r2_score(y_test, rf_preds)))
print("Root Mean Squared Error: {}".format(np.sqrt(mean_squared_error(y_test, rf_preds))))
print("Mean Absolute Error: {}".format(mean_absolute_error(y_test, rf_preds)))
# Out:
# Training Accuracy: 0.8468451745516081
# Testing Accuracy: 0.8209250067930878
# -------------------------------
# R Squared: 0.8209250067930878
# Root Mean Squared Error: 6.5315743319271
# Mean Absolute Error: 5.310117726850701

# %%
sns.kdeplot(y_test)
sns.kdeplot(rf_preds)
plt.legend(['actual','predicted'])

# %%
# Random Forest Feature Importance
rf_feature_imp = rf_reg.feature_importances_
rf_feature_imp
# Out:
# array([0.30437797, 0.04192142, 0.01837718, 0.12725124, 0.06418421,
#        0.0181722 , 0.03235706, 0.39335872])

# %%
columns = df.columns[:-1]
sns.barplot(x=rf_feature_imp, y=columns, orient="h")
plt.title("Random Forest Feature Importances")
# Out:
# Text(0.5, 1.0, 'Random Forest Feature Importances')

# %% [markdown]
# ## CatBoost Regressor

# %%
#cbr = CatBoostRegressor(iterations=100,
#                        learning_rate=0.1,
#                        depth=6,
#                        od_type='Iter',
#                        random_seed=42)
#cbr.fit(X_train_scaled,
#        y_train, 
#        eval_set=(X_test_scaled, y_test),
#        use_best_model=True,
#        verbose=False)

cbr = CatBoostRegressor(depth=5, od_type='Iter', random_seed=42)
cbr.fit(X_train_scaled, y_train, verbose=False)
cbr_preds = cbr.predict(X_test_scaled)

# %%
print("Training Accuracy: {}".format(cbr.score(X_train_scaled, y_train)))
print("Testing Accuracy: {}".format(cbr.score(X_test_scaled, y_test)))
print("-------------------------------")
print("R Squared: {}".format(r2_score(y_test, cbr_preds)))
print("Root Mean Squared Error: {}".format(np.sqrt(mean_squared_error(y_test, cbr_preds))))
print("Mean Absolute Error: {}".format(mean_absolute_error(y_test, cbr_preds)))
# Out:
# Training Accuracy: 0.980180626434316
# Testing Accuracy: 0.9312719729334454
# -------------------------------
# R Squared: 0.9312719729334454
# Root Mean Squared Error: 4.046386289892904
# Mean Absolute Error: 2.688634572627311

# %%
sns.kdeplot(y_test)
sns.kdeplot(cbr_preds)
plt.legend(['actual','predicted'])

# %%
# CatBoostRegressor Features Importances
cbr_feature_imp = cbr.feature_importances_
cbr_feature_imp
# Out:
# array([25.66862432,  9.01659331,  2.91283781, 13.39630927,  7.1405312 ,
#         2.97672966,  5.21936919, 33.66900523])

# %%
sns.barplot(x=cbr_feature_imp, y=columns, orient="h")
plt.title("CatBoostRegressor Feature Importances")
# Out:
# Text(0.5, 1.0, 'CatBoostRegressor Feature Importances')

# %% [markdown]
# ## AdaBoost Regressor

# %%
adb = AdaBoostRegressor(base_estimator=DecisionTreeRegressor(max_depth=5), n_estimators=300, random_state=42)
adb.fit(X_train_scaled, y_train)
adb_preds = adb.predict(X_test_scaled)

# %%
print("Training Accuracy: {}".format(adb.score(X_train_scaled, y_train)))
print("Testing Accuracy: {}".format(adb.score(X_test_scaled, y_test)))
print("-------------------------------")
print("R Squared: {}".format(r2_score(y_test, adb_preds)))
print("Root Mean Squared Error: {}".format(np.sqrt(mean_squared_error(y_test, adb_preds))))
print("Mean Absolute Error: {}".format(mean_absolute_error(y_test, adb_preds)))
# Out:
# Training Accuracy: 0.844146539059996
# Testing Accuracy: 0.8165287487350965
# -------------------------------
# R Squared: 0.8165287487350965
# Root Mean Squared Error: 6.6112626864072395
# Mean Absolute Error: 5.3998479720478505

# %%
sns.kdeplot(y_test)
sns.kdeplot(adb_preds)
plt.legend(['actual','predicted'])

# %%
# AdaBosstRegressor Feature Importances
adb_feature_imp = adb.feature_importances_
adb_feature_imp
# Out:
# array([0.24517228, 0.08167271, 0.02302856, 0.1586833 , 0.07330656,
#        0.09676523, 0.07741626, 0.24395511])

# %%
sns.barplot(x=adb_feature_imp, y=columns, orient="h")
plt.title("AdaBoostRegressor Feature Importances")
# Out:
# Text(0.5, 1.0, 'AdaBoostRegressor Feature Importances')

# %% [markdown]
# ## GradientBoostingRegressor

# %%
gbr = GradientBoostingRegressor(random_state=42)
gbr.fit(X_train_scaled, y_train)
gbr_preds = gbr.predict(X_test_scaled)

# %%
print("Training Accuracy: {}".format(gbr.score(X_train_scaled, y_train)))
print("Testing Accuracy: {}".format(gbr.score(X_test_scaled, y_test)))
print("-------------------------------")
print("R Squared: {}".format(r2_score(y_test, gbr_preds)))
print("Root Mean Squared Error: {}".format(np.sqrt(mean_squared_error(y_test, gbr_preds))))
print("Mean Absolute Error: {}".format(mean_absolute_error(y_test, gbr_preds)))
# Out:
# Training Accuracy: 0.9322703370003513
# Testing Accuracy: 0.9235082958906023
# -------------------------------
# R Squared: 0.9235082958906023
# Root Mean Squared Error: 4.268817321953274
# Mean Absolute Error: 3.3941061521207048

# %%
sns.kdeplot(y_test)
sns.kdeplot(gbr_preds)
plt.legend(['actual','predicted'])

# %%
# GradientBoostingRegressor Feature Importances
gbr_feature_imp = gbr.feature_importances_
gbr_feature_imp
# Out:
# array([0.30562829, 0.06470243, 0.01304899, 0.11672   , 0.07483155,
#        0.01831716, 0.04382007, 0.36293152])

# %%
sns.barplot(x=gbr_feature_imp, y=columns, orient="h")
plt.title("GradientBoostingRegressor Feature Importances")
# Out:
# Text(0.5, 1.0, 'GradientBoostingRegressor Feature Importances')

# %% [markdown]
# ## HistGradientBoostingRegressor

# %%
hgbr = HistGradientBoostingRegressor(max_depth=3, random_state=42)
hgbr.fit(X_train_scaled, y_train)
hgbr_preds = hgbr.predict(X_test_scaled)

# %%
print("Training Accuracy: {}".format(hgbr.score(X_train_scaled, y_train)))
print("Testing Accuracy: {}".format(hgbr.score(X_test_scaled, y_test)))
print("-------------------------------")
print("R Squared: {}".format(r2_score(y_test, hgbr_preds)))
print("Root Mean Squared Error: {}".format(np.sqrt(mean_squared_error(y_test, hgbr_preds))))
print("Mean Absolute Error: {}".format(mean_absolute_error(y_test, hgbr_preds)))
# Out:
# Training Accuracy: 0.921470481448501
# Testing Accuracy: 0.9120835968922881
# -------------------------------
# R Squared: 0.9120835968922881
# Root Mean Squared Error: 4.576519928085755
# Mean Absolute Error: 3.5631203656162773

# %%
sns.kdeplot(y_test)
sns.kdeplot(hgbr_preds)
plt.legend(['actual','predicted'])

# %% [markdown]
# ### LightGBM

# %%
lgbm_reg = LGBMRegressor(max_depth=3)
lgbm_reg.fit(X_train_scaled, y_train)
lgbm_preds = lgbm_reg.predict(X_test)

# %%
print("Training Accuracy: {}".format(lgbm_reg.score(X_train_scaled, y_train)))
print("Testing Accuracy: {}".format(lgbm_reg.score(X_test_scaled, y_test)))
print("-------------------------------")
print("R Squared: {}".format(r2_score(y_test, lgbm_preds)))
print("Root Mean Squared Error: {}".format(np.sqrt(mean_squared_error(y_test, lgbm_preds))))
print("Mean Absolute Error: {}".format(mean_absolute_error(y_test, lgbm_preds)))
# Out:
# Training Accuracy: 0.9200083553370687
# Testing Accuracy: 0.9132899615728506
# -------------------------------
# R Squared: -0.8428317483915886
# Root Mean Squared Error: 20.95285679820462
# Mean Absolute Error: 17.500007872820117

# %%
sns.kdeplot(y_test)
sns.kdeplot(lgbm_preds)
plt.legend(['actual','predicted'])

# %%
# LGBMRegressor Feature Importances
lgbm_feature_imp = lgbm_reg.feature_importances_
lgbm_feature_imp
# Out:
# array([100,  86,  48,  99,  51,  49,  75,  78], dtype=int32)

# %%
sns.barplot(x=lgbm_feature_imp, y=columns, orient="h")
plt.title("LGBMRegressor Feature Importances")
# Out:
# Text(0.5, 1.0, 'LGBMRegressor Feature Importances')

# %% [markdown]
# ## XGBoost

# %%
xgb_reg = XGBRegressor()
xgb_reg.fit(X_train_scaled, y_train)
xgb_preds = xgb_reg.predict(X_test_scaled)

# %%
print("Training Accuracy: {}".format(xgb_reg.score(X_train_scaled, y_train)))
print("Testing Accuracy: {}".format(xgb_reg.score(X_test_scaled, y_test)))
print("-------------------------------")
print("R Squared: {}".format(r2_score(y_test, xgb_preds)))
print("Root Mean Squared Error: {}".format(np.sqrt(mean_squared_error(y_test, xgb_preds))))
print("Mean Absolute Error: {}".format(mean_absolute_error(y_test, xgb_preds)))
# Out:
# Training Accuracy: 0.9960063504488612
# Testing Accuracy: 0.9172791689830027
# -------------------------------
# R Squared: 0.9172791689830027
# Root Mean Squared Error: 4.439232040143669
# Mean Absolute Error: 2.946921120714618

# %%
sns.kdeplot(y_test)
sns.kdeplot(xgb_preds)
plt.legend(['actual','predicted'])

# %%
xgb_feature_imp = xgb_reg.feature_importances_
xgb_feature_imp
# Out:
# array([0.23578925, 0.08788148, 0.06358043, 0.13336861, 0.14855899,
#        0.03747034, 0.05717408, 0.2361768 ], dtype=float32)

# %%
sns.barplot(x=xgb_feature_imp, y=columns, orient="h")
plt.title("XGBRegressor Feature Importances")
# Out:
# Text(0.5, 1.0, 'XGBRegressor Feature Importances')

# %% [markdown]
# ### Evaluation Metrics Table

# %%
## Error table
## hgbr, svr, dtc, rf, gbr, cbr, adb, lgbm
## r2-score, mean-squared-error, mean-absolute-error
models = [svr, dt_reg, rf_reg, gbr, hgbr, xgb_reg, cbr, adb, lgbm_reg]
r_squared = []
rmse = []
mae = []
for model in models:
    preds = model.predict(X_test_scaled)
    r_squared.append(r2_score(y_test, preds))
    rmse.append(np.sqrt(mean_squared_error(y_test, preds)))
    mae.append(mean_absolute_error(y_test, preds))
    
error_table = pd.DataFrame(columns=["Models","R_Squared", "RMSE", "MAE"], index= range(len(models)))
algorithms = ["Support Vector Regressor", 
              "DecisionTreeRegressor",
              "RandomForestRegressor", 
              "GradientBoostingRegressor",
              "HistGradientBoostingRegressor",
              "XGBRegressor",
              "CatBoostRegressor",
              "AdaBoostRegressor",
              "LGBMRegressor"]

error_table["Models"] = algorithms
error_table["R_Squared"] = r_squared
error_table["RMSE"] = rmse
error_table["MAE"] = mae   

error_table
# Out:
#                           Models  R_Squared       RMSE       MAE
# 0       Support Vector Regressor   0.845552   6.065839  3.930403
# 1          DecisionTreeRegressor   0.559876  10.239719  7.993651
# 2          RandomForestRegressor   0.820925   6.531574  5.310118
# 3      GradientBoostingRegressor   0.923508   4.268817  3.394106
# 4  HistGradientBoostingRegressor   0.912084   4.576520  3.563120
# 5                   XGBRegressor   0.917279   4.439232  2.946921
# 6              CatBoostRegressor   0.931272   4.046386  2.688635
# 7              AdaBoostRegressor   0.816529   6.611263  5.399848
# 8                  LGBMRegressor   0.913290   4.545013  3.469069

# %% [markdown]
# ## Feature Importances Table

# %%
feature_imp_table = pd.DataFrame({"DecistionTreeRegressor":dtc_feature_imp,
                                 "RandomForestRegressor": rf_feature_imp, 
                                 "GradientBoostingRegressor": gbr_feature_imp,
                                 "CatBoostRegressor": cbr_feature_imp,
                                 "LGBMRegressor": lgbm_feature_imp,
                                 "XGBRegressor": xgb_feature_imp,
                                 "AdaBoostRegressor": adb_feature_imp,})
feature_imp_table
# Out:
#    DecistionTreeRegressor  RandomForestRegressor  GradientBoostingRegressor  \
# 0                0.432235               0.304378                   0.305628
# 1                0.000000               0.041921                   0.064702
# 2                0.000000               0.018377                   0.013049
# 3                0.100657               0.127251                   0.116720
# 4                0.044804               0.064184                   0.074832
# 5                0.000000               0.018172                   0.018317
# 6                0.000000               0.032357                   0.043820
# 7                0.422303               0.393359                   0.362932
#
#    CatBoostRegressor  LGBMRegressor  XGBRegressor  AdaBoostRegressor
# 0          25.668624            100      0.235789           0.245172
# 1           9.016593             86      0.087881           0.081673
# 2           2.912838             48      0.063580           0.023029
# 3          13.396309             99      0.133369           0.158683
# 4           7.140531             51      0.148559           0.073307
# 5           2.976730             49      0.037470           0.096765
# 6           5.219369             75      0.057174           0.077416
# 7          33.669005             78      0.236177           0.243955
